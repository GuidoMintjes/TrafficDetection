# %%
# !dir
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is 984E-56F3
#
#  Directory of d:\venv\TrafficDetectionAI\TrafficDetection
#
# 24-11-2020  16:50    <DIR>          .
# 24-11-2020  16:50    <DIR>          ..
# 23-11-2020  22:04                15 .gitignore
# 13-11-2020  21:53    <DIR>          .ssh
# 19-11-2020  18:56    <DIR>          .vscode
# 13-11-2020  21:27               158 README.md
# 23-11-2020  21:39                63 requirements.txt
# 24-11-2020  16:50            53.653 TrafficDetection.ipynb
#                4 File(s)         53.889 bytes
#                4 Dir(s)  500.955.385.856 bytes free

# %%
from pycocotools.coco import COCO

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 1000, 100000)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()
