# %%
# Import de coco tools voor de coco dataset ==> (cocodataset.org)
from pycocotools.coco import COCO

import sys

import matplotlib.pyplot as plt
import numpy as np
import os
import skimage.io as io

# %%
print("De COCO 2017 dataset wordt automatisch gedownload, de bosch dataset moet handmatig gedownload worden")
answer = input('Wil je de COCO dataset of de yolov3 bosch dataset gebruiken voor het trainen? (C/Y)')
# Out:
# De COCO 2017 dataset wordt automatisch gedownload, de bosch dataset moet handmatig gedownload worden

# %%
if answer == 'C':
    datadir = '..'
    datatype = 'val2017'
    annFile = '{}/annotations/instances_{}.json'.format(datadir, datatype)

# %%
if answer == 'Y':
    # Functie om te vragen of dit de eerste keer is dat het programma wordt opgestart, voor nu nog niet echt gebruikt!

    # bool recursed, String initString
    def initProgramFirstCheck():
        checked = False
        initBool = False # Standaard nog niet geopend

        while not checked:

            initString = input("Is dit de eerste keer dat je het yolov3 programma opent? (Y/N)")
            
            if initString == "Y":
                initBool = True

            elif initString == "N":
                initBool = False
                
            else:
                print("Verkeerde input, start opnieuw...")
                continue
        
            checked = True
        
        return initBool


    x = initProgramFirstCheck()
    print(x)

# %%
if answer != 'Y' and answer != 'C':
    print("Verkeerde input gekregen, probeer het alstublieft opnieuw!")
    sys.exit()
# Out:
# Verkeerde input gekregen, probeer het alstublieft opnieuw!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
coco = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.80s)
# creating index...
# index created!

# %%
categories = coco.loadCats(coco.getCatIds())
nms = [category['name'] for category in categories]
nms = set([category['supercategory'] for category in categories])

# %%
catIds = coco.getCatIds(catNms=['traffic light'])
imgIds = coco.getImgIds(catIds = catIds)
imgIds = coco.getImgIds(imgIds = [324158])
img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]

# %%
Image = io.imread(img['coco_url'])
plt.axis('off')
plt.imshow(Image)
plt.plot()
# Out:
# []
